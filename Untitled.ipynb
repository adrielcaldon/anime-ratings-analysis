# %%
import sqlite3
import pandas as pd

# Connect to your anime.db
conn = sqlite3.connect("data/anime.db")

# %%
# Show all tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
print("📋 Tables in database:")
print(tables)

# Preview top rows
df = pd.read_sql("SELECT * FROM anime LIMIT 5", conn)
df
# Out:
# 📋 Tables in database:
#     name
# 0  anime
#    score  popularity  rank  members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                               None
# 3                                    Gintama' (2015)
# 4                                               None
#
# ...

# %%
top_anime = pd.read_sql("""
SELECT title, score, rating
FROM anime
ORDER BY score DESC
LIMIT 10
""", conn)
top_anime
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: title
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 top_anime = pd.read_sql("""
#       2 SELECT title, score, rating
#       3 FROM anime
#       4 ORDER BY score DESC
#       5 LIMIT 10
#       6 """, conn)
#       7 top_anime
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
pd.read_sql("PRAGMA table_info(anime)", conn)
# Out:
#     cid         name     type  notnull dflt_value  pk
# 0     0        score     REAL        0       None   0
# 1     1   popularity  INTEGER        0       None   0
# 2     2         rank  INTEGER        0       None   0
# 3     3      members  INTEGER        0       None   0
# 4     4  description     TEXT        0       None   0
# 5     5     synonyms     TEXT        0       None   0
# 6     6     japanese     TEXT        0       None   0
# 7     7      english     TEXT        0       None   0
# 8     8         type     TEXT        0       None   0
# 9     9     episodes     TEXT        0       None   0
# 10   10       status     TEXT        0       None   0
# 11   11        aired     TEXT        0       None   0
# 12   12    premiered     TEXT        0       None   0
# 13   13    broadcast     TEXT        0       None   0
# 14   14    producers     TEXT        0       None   0
# 15   15    licensors     TEXT        0       None   0
# ...

# %%
top_anime = pd.read_sql("""
SELECT name, score, rating
FROM anime
ORDER BY score DESC
LIMIT 10
""", conn)
top_anime
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: name
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 top_anime = pd.read_sql("""
#       2 SELECT name, score, rating
#       3 FROM anime
#       4 ORDER BY score DESC
#       5 LIMIT 10
#       6 """, conn)
#       7 top_anime
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
pd.read_sql("PRAGMA table_info(anime)", conn)
# Out:
#     cid         name     type  notnull dflt_value  pk
# 0     0        score     REAL        0       None   0
# 1     1   popularity  INTEGER        0       None   0
# 2     2         rank  INTEGER        0       None   0
# 3     3      members  INTEGER        0       None   0
# 4     4  description     TEXT        0       None   0
# 5     5     synonyms     TEXT        0       None   0
# 6     6     japanese     TEXT        0       None   0
# 7     7      english     TEXT        0       None   0
# 8     8         type     TEXT        0       None   0
# 9     9     episodes     TEXT        0       None   0
# 10   10       status     TEXT        0       None   0
# 11   11        aired     TEXT        0       None   0
# 12   12    premiered     TEXT        0       None   0
# 13   13    broadcast     TEXT        0       None   0
# 14   14    producers     TEXT        0       None   0
# 15   15    licensors     TEXT        0       None   0
# ...

# %%
top_anime = pd.read_sql("""
SELECT name, score, rating
FROM anime
ORDER BY score DESC
LIMIT 10
""", conn)

top_anime
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: name
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 top_anime = pd.read_sql("""
#       2 SELECT name, score, rating
#       3 FROM anime
#       4 ORDER BY score DESC
#       5 LIMIT 10
#       6 """, conn)
#       8 top_anime
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
pd.read_sql("SELECT * FROM anime LIMIT 1", conn)
# Out:
#    score  popularity  rank  members  \
# 0   9.38         284     1      710
#
#                                          description                synonyms  \
# 0  During their decade-long quest to defeat the D...  Frieren at the Funeral
#
#    japanese                        english type episodes  ...  premiered  \
# 0  葬送のフリーレン  Frieren: Beyond Journey's End   TV       28  ...  Fall 2023
#
#                 broadcast                                          producers  \
# 0  Fridays at 23:00 (JST)  Aniplex, Dentsu, Shogakukan-Shueisha Productio...
#
#               licensors   studios source  \
# 0  None found, add some  Madhouse  Manga
#
#                                            genres     demographic  \
# 0  AdventureAdventure, DramaDrama, FantasyFantasy  ShounenShounen
#
#           duration                     rating
# 0  24 min. per ep.  PG-13 - Teens 13 or older
#
# [1 rows x 22 columns]
